# %% [markdown]
# __1.__ Решить систему уравнений методом Гаусса:
#
# $$\begin{cases}
# x_{1}+x_{2}-x_{3}-2x_{4}=0, \\
# 2x_{1}+x_{2}-x_{3}+x_{4}=-2, \\
# x_{1}+x_{2}-3x_{3}+x_{4}=4.
# \end{cases}$$
#
# __2.__ Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений:
#
#    а) $\begin{cases}
# 3x_{1}-x_{2}+x_{3}=4, \\
# 2x_{1}-5x_{2}-3x_{3}=-17, \\
# x_{1}+x_{2}-x_{3}=0;
# \end{cases}$
#
#    б) $\begin{cases}
# 2x_{1}-4x_{2}+6x_{3}=1, \\
# x_{1}-2x_{2}+3x_{3}=-2, \\
# 3x_{1}-6x_{2}+9x_{3}=5;
# \end{cases}$
#
#    в) $\begin{cases}
# x_{1}+2x_{2}+5x_{3}=4, \\
# 3x_{1}+x_{2}-8x_{3}=-2.
# \end{cases}$
#
#
# __3.__ Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений, заданная расширенной матрицей
#
# $$\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 3 & -2 & 4\\
# 0 & 5 & 0 & 1\\
# 0 & 0 & 3 & 0\\
# 0 & 0 & 0 & 2
# \end{matrix}\right|
# \begin{matrix}
# 3\\
# 2\\
# 4\\
# 1
# \end{matrix}
# \end{pmatrix}.$$
#
# __4.__ Дана система линейных уравнений, заданная расширенной матрицей
#
# $$\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b\\
# c
# \end{matrix}
# \end{pmatrix}.$$
#
# Найти соотношение между параметрами $a$, $b$ и $c$, при которых система является несовместной.

# %% [markdown]
# __1.__ Решить систему уравнений методом Крамера:
#
#    а) $\begin{cases}
# x_{1}-2x_{2}=1 \\
# 3x_{1}-4x_{2}=7
# \end{cases}$
#
#    б) $\begin{cases}
# 2x_{1}-x_{2}+5x_{3}=10 \\
# x_{1}+x_{2}-3x_{3}=-2 \\
# 2x_{1}+4x_{2}+x_{3}=1
# \end{cases}$
#
# __2*.__ Найти $L$-матрицу $LU$-разложения для матрицы коэффициентов:
#
#    а)$$\begin{pmatrix}
# 1 & 2 & 4 \\
# 2 & 9 & 12 \\
# 3 & 26 & 30
# \end{pmatrix}$$
#
#    б)$$\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 2 & 5 & 8 & 9\\
# 3 & 18 & 29 & 18\\
# 4 & 22 & 53 & 33
# \end{pmatrix}$$
#
# __3*.__ Решить систему линейных уравнений методом $LU$-разложения
#
# $$\begin{cases}
# 2x_{1}+x_{2}+3x_{3}=1 \\
# 11x_{1}+7x_{2}+5x_{3}=-6 \\
# 9x_{1}+8x_{2}+4x_{3}=-5
# \end{cases}$$
#
# __4*.__ Решить систему линейных уравнений методом Холецкого
#
# $$\begin{cases}
# 81x_{1}-45x_{2}+45x_{3}=531 \\
# -45x_{1}+50x_{2}-15x_{3}=-460 \\
# 45x_{1}-15x_{2}+38x_{3}=193
# \end{cases}$$
#
# __5*.__ Написать на Python программу с реализацией одного из изученных алгоритмов решения СЛАУ.

# %% [markdown]
# __1.__ Решить систему уравнений методом Гаусса:
#
# $$\begin{cases}
# x_{1}+x_{2}-x_{3}-2x_{4}=0, \\
# 2x_{1}+x_{2}-x_{3}+x_{4}=-2, \\
# x_{1}+x_{2}-3x_{3}+x_{4}=4.
# \end{cases}$$

# %% [markdown]
# Запишем расширенную матрицу системы:
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2\\
# 2 & 1 & -1 & 1 \\
# 1 & 1 & -3 & 1
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -2\\
# 4
# \end{matrix}
# \end{pmatrix}.$$
#
# Путем элементарных преобразований постараемся привести матрицу к ступенчатому виду.
#
# Вычтем из второй строки первую, умноженную на 2:
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2\\
# 0 & -1 & 1 & 5 \\
# 1 & 1 & -3 & 1
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -2\\
# 4
# \end{matrix}
# \end{pmatrix}.$$
#
# Вычтем из третьей строки первую:
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2\\
# 0 & -1 & 1 & 5 \\
# 0 & 0 & -2 & 3
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -2\\
# 4
# \end{matrix}
# \end{pmatrix}.$$

# %% [markdown]
# В итоге после преобразований мы получили матрицу треугльного вида, которая представляет следующую систему:
#
# $$\begin{cases}
# x_{1}+x_{2}-x_{3}-2x_{4}=0, \\
# ~~~~-x_{2}+x_{3}+5x_{4}=-2, \\
# ~~~~~~~~~~-2x_{3}+3x_{4}=4.
# \end{cases}$$
#
# Проводя обратный ход метода Гаусса, последовательн подставляя известные значения в уравнения, получим
#
# $$x_{3}=-2.$$
#
# Подставим $x_{3}$ а затем получим:
# $$x_{1}=-2.$$ $$x_{2}=0.$$ $$x_{4}=0.$$
#
#
# Если подставить полученные значения неизвестных в исходную систему, несложно убедиться, что все выражения обращаются в тождества:
#
# $$\begin{cases}
# 1\cdot(-2)+1\cdot0-1\cdot(-2)-2\cdot0=0,\\
# 2\cdot(-2)+1\cdot0-1\cdot(-2)+1\cdot0=-2,\\
# 1\cdot(-2)+1\cdot0-3\cdot(-2)+1\cdot0=4.
# \end{cases}$$

# %% [markdown]
# 2.__ Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений:
#
#    а) $\begin{cases}
# 3x_{1}-x_{2}+x_{3}=4, \\
# 2x_{1}-5x_{2}-3x_{3}=-17, \\
# x_{1}+x_{2}-x_{3}=0;
# \end{cases}$
#
#    б) $\begin{cases}
# 2x_{1}-4x_{2}+6x_{3}=1, \\
# x_{1}-2x_{2}+3x_{3}=-2, \\
# 3x_{1}-6x_{2}+9x_{3}=5;
# \end{cases}$
#
#    в) $\begin{cases}
# x_{1}+2x_{2}+5x_{3}=4, \\
# 3x_{1}+x_{2}-8x_{3}=-2.
# \end{cases}$

# %% [markdown]
#   а) $\begin{cases}
# 3x_{1}-x_{2}+x_{3}=4, \\
# 2x_{1}-5x_{2}-3x_{3}=-17, \\
# x_{1}+x_{2}-x_{3}=0;
# \end{cases}$
# Число уравнений равно числу неизвестных
#
# Перепишем эту систему в векторном виде:
#
# $$x_{1}\begin{pmatrix}
# 3\\
# 2\\
# 1
# \end{pmatrix}+
# x_{2}\begin{pmatrix}
# -1\\
# -5\\
# 1
# \end{pmatrix}+
# x_{3}\begin{pmatrix}
# 1\\
# -3\\
# -1
# \end{pmatrix}=
# \begin{pmatrix}
# 4\\
# -17\\
# 0
# \end{pmatrix} \Leftrightarrow x_{1}a_{1}+x_{2}a_{2}+x_{3}a_{3}=b$$

# %% [markdown]
# Запишем расширенную матрицу системы:
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 3 & -1 & 1\\
# 2 & -5 & -3\\
# 1 & 1 & -1
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# -17\\
# 0
# \end{matrix}
# \end{pmatrix}.$$
#
# Вычтем из 2 строки 3 умноженну на 2:
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 3 & -1 & 1\\
# 0 & -7 & -1\\
# 1 & 1 & -1
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# -17\\
# 0
# \end{matrix}
# \end{pmatrix}.$$
#
#
# Вычтем из 1 строки 3 умноженну на 3:
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 0 & -2 & 2\\
# 0 & -7 & -1\\
# 1 & 1 & -1
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# -17\\
# 0
# \end{matrix}
# \end{pmatrix}.$$
#
# $$x_{1}=19/8.$$ $$x_{2}=38/8.$$ $$x_{3}=19/8.$$   Такая система несовместна.

# %% [markdown]
#   б) $\begin{cases}
# 2x_{1}-4x_{2}+6x_{3}=1, \\
# x_{1}-2x_{2}+3x_{3}=-2, \\
# 3x_{1}-6x_{2}+9x_{3}=5;
# \end{cases}$
#
# Запишем расширенную матрицу системы:
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 2 & -4 & 6\\
# 1 & -2 & 3\\
# 3 & -6 & 9
# \end{matrix}\right|
# \begin{matrix}
# 1\\
# -2\\
# 5
# \end{matrix}
# \end{pmatrix}.$$
#
# Сумма 1 и 2 строки дают 3:
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 3 & -6 & 9
# \end{matrix}\right|
# \begin{matrix}
# 5
# \end{matrix}
# \end{pmatrix}.$$

# %% [markdown]
#  При этом, решений больше одного — система является _неопределенной_ и _совместимой_.

# %% [markdown]
# в) $\begin{cases}
# x_{1}+2x_{2}+5x_{3}=4, \\
# 3x_{1}+x_{2}-8x_{3}=-2.
# \end{cases}$
#
# Число уравнений меньше числа неизвестных. Система будет совместимой и иметь бесконеное множестов решений.

# %% [markdown]
# 3.__ Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений, заданная расширенной матрицей
#
# $$\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 3 & -2 & 4\\
# 0 & 5 & 0 & 1\\
# 0 & 0 & 3 & 0\\
# 0 & 0 & 0 & 2
# \end{matrix}\right|
# \begin{matrix}
# 3\\
# 2\\
# 4\\
# 1
# \end{matrix}
# \end{pmatrix}.$$

# %% [markdown]
# $$x_{1}=8.1.$$ $$x_{2}=0.3.$$ $$x_{3}=4.$$ $$x_{4}=0.5.$$  Такая система совместна. rankA~=4 и  rankA=4

# %% [markdown]
# 4.__ Дана система линейных уравнений, заданная расширенной матрицей
#
# $$\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b\\
# c
# \end{matrix}
# \end{pmatrix}.$$
#
# Найти соотношение между параметрами $a$, $b$ и $c$, при которых система является несовместной.

# %% [markdown]
# если $rankA<rank \tilde A$, то система несовместна.

# %% [markdown]
# Вычтем из второй строки первую, умноженную на 4:
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 0 & -3 & -6 \\
# 7 & 8 & 9
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b-a
# c
# \end{matrix}
# \end{pmatrix}.$$
#
# Вычтем из 3 строки первую, умноженную на 7:
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 0 & -3 & -6 \\
# 0 & -6 & -12
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b-a\\
# c-a
# \end{matrix}
# \end{pmatrix}.$$
#
# Вычтем из 3 строки 2, умноженную на 2:
#
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 0 & -3 & -6 \\
# 0 & 0 & 0
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b-a\\
# c-b
# \end{matrix}
# \end{pmatrix}.$$

# %% [markdown]
# Если  c-b≠0 , то  rankA~=3, в то время как  rankA=2 . Это означает, что система в этом случае несовместна.

# %% [markdown]
# __1.__ Решить систему уравнений методом Крамера:
#
#    а) $\begin{cases}
# x_{1}-2x_{2}=1 \\
# 3x_{1}-4x_{2}=7
# \end{cases}$
#
#    б) $\begin{cases}
# 2x_{1}-x_{2}+5x_{3}=10 \\
# x_{1}+x_{2}-3x_{3}=-2 \\
# 2x_{1}+4x_{2}+x_{3}=1
# \end{cases}$

# %% [markdown]
# Найдем определитель матрицы коэффициентов:
#
# $$detA=\begin{vmatrix}
# 1 & -2 \\
# 3 & -4
# \end{vmatrix}=
# 1\cdot(-4)-(-2)\cdot3=8\neq 0,$$
#
# следовательно, система совместна.
#
# Найдем определители $detA_{1}$, $detA_{2}$:
#
# $$detA_{1}=\begin{vmatrix}
# 1 & -2\\
# 7 & -4
# \end{vmatrix}=
# 1\cdot(-4)-(-2)\cdot7=18.$$
#
# $$detA_{2}=\begin{vmatrix}
# 1 & 1\\
# 3 & 7
# \end{vmatrix}=
# 1\cdot7-1\cdot3=4.$$
#
# Найдем решение по формулам Крамера:
#
# $$x_{1} = \frac{detA_{1}}{detA} = \frac{18}{8}=2.25,$$
#
# $$x_{2} = \frac{detA_{2}}{detA} = \frac{4}{8}=0.5,$$

# %% [markdown]
#  б) $\begin{cases}
# 2x_{1}-x_{2}+5x_{3}=10 \\
# x_{1}+x_{2}-3x_{3}=-2 \\
# 2x_{1}+4x_{2}+x_{3}=1
# \end{cases}$
#
# __Решение__
#
# Найдем определитель матрицы коэффициентов:
#
# $$detA=\begin{vmatrix}
# 2 & -1 & 5\\
# 1 & 1 & -3\\
# 2 & 4 & 1
# \end{vmatrix}=
# 2\begin{vmatrix}
# 1 & -3\\
# 4 & 1
# \end{vmatrix}+
# 1\begin{vmatrix}
# 1 & -3\\
# 2 & 1
# \end{vmatrix}+5
# \begin{vmatrix}
# 1 & 1 \\
# 2 & 4
# \end{vmatrix}=2(1 \cdot 1+3\cdot 4)+1(1\cdot 1+3\cdot 2)+5(1\cdot 4-1\cdot 2)=50\neq 0,$$
#
# следовательно, система совместна.
#
# Найдем определители $detA_{1}$, $detA_{2}$, $detA_{3}$:
#
# $$detA_{1}=\begin{vmatrix}
# 10 & -1 & 5\\
# 2 & 1 & -3\\
# 1 & 4 & 1
# \end{vmatrix}=
# 10\begin{vmatrix}
# 1 & -3\\
# 4 & 1
# \end{vmatrix}+
# 1\begin{vmatrix}
# 2 & -3\\
# 1 & 1
# \end{vmatrix}+5
# \begin{vmatrix}
# 2 & 1 \\
# 1 & 4
# \end{vmatrix}=10(1 \cdot 1+3\cdot 4)+1(2\cdot 1+3\cdot 1)+5(2\cdot 4-1\cdot 1)=170,$$
#
# $$detA_{2}=\begin{vmatrix}
# 2 & 10 & 5\\
# 1 & 2 & -3\\
# 2 & 1 & 1
# \end{vmatrix}=
# 2\begin{vmatrix}
# 2 & -3\\
# 1 & 1
# \end{vmatrix}-
# 10\begin{vmatrix}
# 1 & -3\\
# 2 & 1
# \end{vmatrix}+5
# \begin{vmatrix}
# 1 & 2 \\
# 2 & 1
# \end{vmatrix}=2(2 \cdot 1+3\cdot 1)-10(1\cdot 1+3\cdot 2)+5(1\cdot 1-2\cdot 2)=-75,$$
#
# $$detA_{3}=\begin{vmatrix}
# 2 & -1 & 10\\
# 1 & 1 & 2\\
# 2 & 4 & 1
# \end{vmatrix}=
# 2\begin{vmatrix}
# 1 & 2\\
# 4 & 1
# \end{vmatrix}+
# 1\begin{vmatrix}
# 1 & 2\\
# 2 & 1
# \end{vmatrix}+10
# \begin{vmatrix}
# 1 & 1 \\
# 2 & 4
# \end{vmatrix}=2(1 \cdot -2\cdot 4)+1(1\cdot 1-2\cdot 2)+10(1\cdot 4-1\cdot 2)=3,$$
#
# Найдем решение по формулам Крамера:
#
# $$x_{1} = \frac{detA_{1}}{detA} = \frac{170}{50}=3.4,$$
#
# $$x_{2} = \frac{detA_{2}}{detA} = \frac{-75}{50}=-1.5,$$
#
# $$x_{3} = \frac{detA_{3}}{detA} = \frac{3}{50}=0.06.$$

# %% [markdown]
# 2*.__ Найти $L$-матрицу $LU$-разложения для матрицы коэффициентов:
#
#    а)$$\begin{pmatrix}
# 1 & 2 & 4 \\
# 2 & 9 & 12 \\
# 3 & 26 & 30
# \end{pmatrix}$$
#
#    б)$$\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 2 & 5 & 8 & 9\\
# 3 & 18 & 29 & 18\\
# 4 & 22 & 53 & 33
# \end{pmatrix}$$

# %% [markdown]
# а) Начнем прямой ход метода Гаусса. Для этого домножим первую строку на $2$ и вычтем ее из второго уравнения. При этом запишем в матрицу $L$ на место элемента $l_{21}$ значение $2$. Затем нам нужно вычесть из третьего уравнения первое, домноженное на $(3)$. Значит, в матрицу $L$ запишем $l_{31}=3$.
#
# Матрица коэффициентов будет иметь вид
#
# $$\begin{pmatrix}
# 1 & 2 & 4 \\
# 0 & 5 & 4 \\
# 0 & 20 & 18
# \end{pmatrix},$$
#
# а матрица $L$ —
#
# $$\begin{pmatrix}
# 1 & 0 & 0 \\
# 2 & 1 & 0 \\
# 3 & l_{32} & 1
# \end{pmatrix}.$$

# %% [markdown]
# Далее умножим вторую строку на $(4)$ и вычтем ее из третьей. При этом в матрицу $L$ на место $l_{32}$ запишем $4$.
#
# В итоге получим
#
# $$U=\begin{pmatrix}
# 1 & 2 & 4 \\
# 0 & 5 & 4 \\
# 0 & 0 & 2
# \end{pmatrix},$$
#
# $$L=\begin{pmatrix}
# 1 & 0 & 0 \\
# 2 & 1 & 0 \\
# 3 & 4 & 1
# \end{pmatrix}.$$

# %% [markdown]
# б)$$\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 2 & 5 & 8 & 9\\
# 3 & 18 & 29 & 18\\
# 4 & 22 & 53 & 33
# \end{pmatrix}$$

# %% [markdown]
# б) Начнем прямой ход метода Гаусса. Для этого домножим первую строку на $2$ и вычтем ее из второго уравнения. При этом запишем в матрицу $L$ на место элемента $l_{21}$ значение $2$. Затем нам нужно вычесть из третьего уравнения первое, домноженное на $(3)$. Значит, в матрицу $L$ запишем $l_{31}=3$. Затем нам нужно вычесть из четвертого уравнения первое, домноженное на $(4)$. Значит, в матрицу $L$ запишем $l_{41}=4$.
#
# Матрица коэффициентов будет иметь вид
#
# $$\begin{pmatrix}
# 1 & 1 & 2 & 4  \\
# 0 & 3 & 4 & 1 \\
# 0 & 15 & 23 & 6 \\
# 0 & 18 & 45 & 17
# \end{pmatrix},$$
#
# а матрица $L$ —
#
# $$\begin{pmatrix}
# 1 & 0 & 0 & 0 \\
# 2 & 1 & 0 & 0 \\
# 3 & l_{32} & 1 & 0 \\
# 4 & l_{42} & l_{43} & 1
# \end{pmatrix}.$$

# %% [markdown]
# Далее умножим вторую строку на $(5)$ и вычтем ее из третьей. При этом в матрицу $L$ на место $l_{32}$ запишем $5$. Затем умножим вторую строку на $(6)$ и вычтем ее из четвертой. При этом в матрицу $L$ на место $l_{42}$ запишем $6$.
#
# В итоге получим
#
# $$U=\begin{pmatrix}
# 1 & 1 & 2 & 4 \\
# 0 & 3 & 4 & 1 \\
# 0 & 0 & 3 & 1 \\
# 0 & 0 & 21 & 11
# \end{pmatrix},$$
#
# $$L=\begin{pmatrix}
# 1 & 0 & 0 & 0  \\
# 2 & 1 & 0 & 0  \\
# 2 & 5 & 1 & 0  \\
# 3 & 6 & l_{43} & 1
# \end{pmatrix}.$$

# %% [markdown]
# Далее умножим 3 строку на $(7)$ и вычтем ее из 4. При этом в матрицу $L$ на место $l_{43}$ запишем $7$.
# В итоге получим
#
# $$U=\begin{pmatrix}
# 1 & 1 & 2 & 4 \\
# 0 & 3 & 4 & 1 \\
# 0 & 0 & 3 & 1 \\
# 0 & 0 & 0 & 4
# \end{pmatrix},$$
#
# $$L=\begin{pmatrix}
# 1 & 0 & 0 & 0  \\
# 2 & 1 & 0 & 0  \\
# 2 & 5 & 1 & 0  \\
# 3 & 6 & 7 & 1
# \end{pmatrix}.$$
